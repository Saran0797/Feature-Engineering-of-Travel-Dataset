# %% [markdown]
# Handling Categorical Variables using different methods

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('https://raw.githubusercontent.com/arijitbose/Feature_engineering/main/Travel.csv')
data
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %%
dt = data.copy()

# %%
dt.drop('CustomerID', axis=1, inplace=True)

# %%
categorical_feature = [feature for feature in dt.columns if dt[feature].dtype=='O']
categorical_feature
# Out:
# ['TypeofContact',
#  'Occupation',
#  'Gender',
#  'ProductPitched',
#  'MaritalStatus',
#  'Designation']

# %%
dt[categorical_feature].isnull().sum()
# Out:
# TypeofContact     25
# Occupation         0
# Gender             0
# ProductPitched     0
# MaritalStatus      0
# Designation        0
# dtype: int64

# %%
def filling_null(data, feature):
    mode = data[feature].mode()[0]
    data[feature] = data[feature].fillna(mode)

# %%
filling_null(dt, 'TypeofContact')

# %%
dt.TypeofContact.isnull().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()

# %%
dt['TypeofContact'] = label.fit_transform(dt.TypeofContact)

# %%
dt.TypeofContact.unique()
# Out:
# array([1, 0])

# %%
for feature in dt[categorical_feature]:
    dt[feature] = label.fit_transform(dt[feature])

# %%
dt
# Out:
#       ProdTaken   Age  TypeofContact  CityTier  DurationOfPitch  Occupation  \
# 0             1  41.0              1         3              6.0           2
# 1             0  49.0              0         1             14.0           2
# 2             1  37.0              1         1              8.0           0
# 3             0  33.0              0         1              9.0           2
# 4             0   NaN              1         1              8.0           3
# ...         ...   ...            ...       ...              ...         ...
# 4883          1  49.0              1         3              9.0           3
# 4884          1  28.0              0         1             31.0           2
# 4885          1  52.0              1         3             17.0           2
# 4886          1  19.0              1         3             16.0           3
# 4887          1  36.0              1         1             14.0           2
#
# ...

# %%
dp = data.copy()
dp
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
one = OneHotEncoder(drop='first')
one
# Out:
# OneHotEncoder(drop='first')

# %%
re = dp.TypeofContact.to_numpy()
re
# Out:
# array(['Self Enquiry', 'Company Invited', 'Self Enquiry', ...,
#        'Self Enquiry', 'Self Enquiry', 'Self Enquiry'], dtype=object)

# %%
dp['TypeofContact'] = pd.get_dummies(dp.TypeofContact, drop_first=True)

# %%
dp
# Out:
#       CustomerID  ProdTaken   Age  TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0              1         3              6.0
# 1         200001          0  49.0              0         1             14.0
# 2         200002          1  37.0              1         1              8.0
# 3         200003          0  33.0              0         1              9.0
# 4         200004          0   NaN              1         1              8.0
# ...          ...        ...   ...            ...       ...              ...
# 4883      204883          1  49.0              1         3              9.0
# 4884      204884          1  28.0              0         1             31.0
# 4885      204885          1  52.0              1         3             17.0
# 4886      204886          1  19.0              1         3             16.0
# 4887      204887          1  36.0              1         1             14.0
#
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ord = OrdinalEncoder()

# %%
dd = data.copy()

# %%
category = [feature for feature in dd.columns if dd[feature].dtype=='O']
category
# Out:
# ['TypeofContact',
#  'Occupation',
#  'Gender',
#  'ProductPitched',
#  'MaritalStatus',
#  'Designation']

# %%
dd.TypeofContact.unique()
# Out:
# array(['Self Enquiry', 'Company Invited', nan], dtype=object)

# %%
dd.TypeofContact = dd.TypeofContact.fillna(dd.TypeofContact.mode()[0])

# %%
dd.TypeofContact.map({'Self Enquiry':0, 'Company Invited':1})
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       0
#        ..
# 4883    0
# 4884    1
# 4885    0
# 4886    0
# 4887    0
# Name: TypeofContact, Length: 4888, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
one = OneHotEncoder(drop='first')
one
# Out:
# OneHotEncoder(drop='first')

# %%
dd = one.fit_transform(data[category])

# %%
dd
# Out:
# <4888x18 sparse matrix of type '<class 'numpy.float64'>'
# 	with 24618 stored elements in Compressed Sparse Row format>
