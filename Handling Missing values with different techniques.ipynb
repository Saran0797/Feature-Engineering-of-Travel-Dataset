# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('https://raw.githubusercontent.com/arijitbose/Feature_engineering/main/Travel.csv')

# %%
data.head(5)
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   int64
#  2   Age                       4662 non-null   float64
#  3   TypeofContact             4863 non-null   object
#  4   CityTier                  4888 non-null   int64
#  5   DurationOfPitch           4637 non-null   float64
#  6   Occupation                4888 non-null   object
#  7   Gender                    4888 non-null   object
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4843 non-null   float64
#  10  ProductPitched            4888 non-null   object
#  11  PreferredPropertyStar     4862 non-null   float64
#  12  MaritalStatus             4888 non-null   object
# ...

# %% [markdown]
# filling numerical variables with mean values

# %%
categorical_variables = [feature for feature in data.columns if data[feature].dtype=='O']
categorical_variables
# Out:
# ['TypeofContact',
#  'Occupation',
#  'Gender',
#  'ProductPitched',
#  'MaritalStatus',
#  'Designation']

# %%
numerical_variables = [feature for feature in data.columns if data[feature].dtype!='O']
numerical_variables
# Out:
# ['CustomerID',
#  'ProdTaken',
#  'Age',
#  'CityTier',
#  'DurationOfPitch',
#  'NumberOfPersonVisiting',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'Passport',
#  'PitchSatisfactionScore',
#  'OwnCar',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome']

# %%
data[categorical_variables].isnull().sum()
# Out:
# TypeofContact     25
# Occupation         0
# Gender             0
# ProductPitched     0
# MaritalStatus      0
# Designation        0
# dtype: int64

# %%
data[numerical_variables].isnull().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                         226
# CityTier                      0
# DurationOfPitch             251
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# PreferredPropertyStar        26
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# MonthlyIncome               233
# dtype: int64

# %%
for feature in data[numerical_variables]:
    mean = data[feature].mean()
    data[feature] = data[feature].fillna(mean)

# %%
data[numerical_variables].isnull().sum()
# Out:
# CustomerID                  0
# ProdTaken                   0
# Age                         0
# CityTier                    0
# DurationOfPitch             0
# NumberOfPersonVisiting      0
# NumberOfFollowups           0
# PreferredPropertyStar       0
# NumberOfTrips               0
# Passport                    0
# PitchSatisfactionScore      0
# OwnCar                      0
# NumberOfChildrenVisiting    0
# MonthlyIncome               0
# dtype: int64

# %% [markdown]
# filling numerical and categorical variables using sklearn function

# %%
from sklearn.impute import SimpleImputer

# %%
x = SimpleImputer(strategy='mean')

# %%
data = pd.read_csv('https://raw.githubusercontent.com/arijitbose/Feature_engineering/main/Travel.csv')

# %%
data.isnull().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                         226
# TypeofContact                25
# CityTier                      0
# DurationOfPitch             251
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
numerical = [feature for feature in data.columns if data[feature].dtype!='O']
numerical
# Out:
# ['CustomerID',
#  'ProdTaken',
#  'Age',
#  'CityTier',
#  'DurationOfPitch',
#  'NumberOfPersonVisiting',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'Passport',
#  'PitchSatisfactionScore',
#  'OwnCar',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome']

# %%
data[numerical] = pd.DataFrame(x.fit_transform(data[numerical]),columns=[['CustomerID',
 'ProdTaken',
 'Age',
 'CityTier',
 'DurationOfPitch',
 'NumberOfPersonVisiting',
 'NumberOfFollowups',
 'PreferredPropertyStar',
 'NumberOfTrips',
 'Passport',
 'PitchSatisfactionScore',
 'OwnCar',
 'NumberOfChildrenVisiting',
 'MonthlyIncome']])

# %%
y =SimpleImputer(strategy='most_frequent')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   float64
#  1   ProdTaken                 4888 non-null   float64
#  2   Age                       4888 non-null   float64
#  3   TypeofContact             4863 non-null   object
#  4   CityTier                  4888 non-null   float64
#  5   DurationOfPitch           4888 non-null   float64
#  6   Occupation                4888 non-null   object
#  7   Gender                    4888 non-null   object
#  8   NumberOfPersonVisiting    4888 non-null   float64
#  9   NumberOfFollowups         4888 non-null   float64
#  10  ProductPitched            4888 non-null   object
#  11  PreferredPropertyStar     4888 non-null   float64
#  12  MaritalStatus             4888 non-null   object
# ...

# %%
categorical = [feature for feature in data.columns if data[feature].dtype=='O']
categorical
# Out:
# ['TypeofContact',
#  'Occupation',
#  'Gender',
#  'ProductPitched',
#  'MaritalStatus',
#  'Designation']

# %%
data[categorical] = pd.DataFrame(y.fit_transform(data[categorical]), columns=[['TypeofContact',
 'Occupation',
 'Gender',
 'ProductPitched',
 'MaritalStatus',
 'Designation']])

# %%
data.isnull().sum()
# Out:
# CustomerID                  0
# ProdTaken                   0
# Age                         0
# TypeofContact               0
# CityTier                    0
# DurationOfPitch             0
# Occupation                  0
# Gender                      0
# NumberOfPersonVisiting      0
# NumberOfFollowups           0
# ProductPitched              0
# PreferredPropertyStar       0
# MaritalStatus               0
# NumberOfTrips               0
# Passport                    0
# PitchSatisfactionScore      0
# OwnCar                      0
# NumberOfChildrenVisiting    0
# Designation                 0
# MonthlyIncome               0
# dtype: int64

# %% [markdown]
# filling categorical variable with mode

# %%
data = pd.read_csv('https://raw.githubusercontent.com/arijitbose/Feature_engineering/main/Travel.csv')
data.isnull().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                         226
# TypeofContact                25
# CityTier                      0
# DurationOfPitch             251
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
mode = data.TypeofContact.mode()[0]
mode
# Out:
# 'Self Enquiry'

# %%
data['TypeofContact'] = data.TypeofContact.fillna(mode)
data.TypeofContact
# Out:
# 0          Self Enquiry
# 1       Company Invited
# 2          Self Enquiry
# 3       Company Invited
# 4          Self Enquiry
#              ...
# 4883       Self Enquiry
# 4884    Company Invited
# 4885       Self Enquiry
# 4886       Self Enquiry
# 4887       Self Enquiry
# Name: TypeofContact, Length: 4888, dtype: object

# %%
data.TypeofContact.isnull().sum()
# Out:
# 0

# %%
data = pd.read_csv('https://raw.githubusercontent.com/arijitbose/Feature_engineering/main/Travel.csv')
data
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %%
max(data.Age), min(data.Age)
# Out:
# (61.0, 18.0)

# %%
z = SimpleImputer(strategy='constant', fill_value=50)

# %%
array = data.Age.to_numpy()

# %%
array.reshape(-1,1)
# Out:
# array([[41.],
#        [49.],
#        [37.],
#        ...,
#        [52.],
#        [19.],
#        [36.]])

# %%
data.Age = z.fit_transform(array.reshape(-1,1))

# %%
data.Age.isnull().sum()
# Out:
# 0

# %%
numerical_null = [feature for feature in data.columns if data[feature].dtype!='O' and data[feature].isnull().sum()>0]
numerical_null
# Out:
# ['DurationOfPitch',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome']

# %%
for feature in data[numerical_null]:
    array = data[feature].to_numpy()
    p = array.reshape(-1,1)
    data[feature] = z.fit_transform(p)

# %%
data[numerical_null].isnull().sum()
# Out:
# DurationOfPitch             0
# NumberOfFollowups           0
# PreferredPropertyStar       0
# NumberOfTrips               0
# NumberOfChildrenVisiting    0
# MonthlyIncome               0
# dtype: int64

# %%
categorical_null = [feature for feature in data.columns if data[feature].dtype=='O' and data[feature].isnull().sum()>0]
categorical_null
# Out:
# ['TypeofContact']

# %%
miss = SimpleImputer(strategy='constant', fill_value='missing')
miss
# Out:
# SimpleImputer(fill_value='missing', strategy='constant')

# %%
data['TypeofContact'] = pd.DataFrame(miss.fit_transform(data[categorical_null]))
data['TypeofContact']
# Out:
# 0          Self Enquiry
# 1       Company Invited
# 2          Self Enquiry
# 3       Company Invited
# 4          Self Enquiry
#              ...
# 4883       Self Enquiry
# 4884    Company Invited
# 4885       Self Enquiry
# 4886       Self Enquiry
# 4887       Self Enquiry
# Name: TypeofContact, Length: 4888, dtype: object

# %%
data.TypeofContact.isnull().sum()
# Out:
# 0

# %%
data.TypeofContact.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Replacing missing values with a value at the end of the distribution

# %%
data = pd.read_csv('https://raw.githubusercontent.com/arijitbose/Feature_engineering/main/Travel.csv')
data
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %%
null_numerical = [feature for feature in data.columns if data[feature].dtype!='O' and data[feature].isnull().sum()>0]
null_numerical
# Out:
# ['Age',
#  'DurationOfPitch',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome']

# %%
for feature in data[null_numerical]:
    upper_quantile = data[feature].quantile(0.75)
    lower_quantile = data[feature].quantile(0.25)
    inter_quantile = upper_quantile - lower_quantile
    upper_boundary = upper_quantile+(1.5*inter_quantile)
    z = SimpleImputer(strategy='constant', fill_value=upper_boundary)
    array = data[feature].to_numpy()
    p = array.reshape(-1,1)
    data[feature] = z.fit_transform(p)

# %% [markdown]
# Doing the same with feature Engine

# %%
data[null_numerical].isnull().sum()
# Out:
# Age                         0
# DurationOfPitch             0
# NumberOfFollowups           0
# PreferredPropertyStar       0
# NumberOfTrips               0
# NumberOfChildrenVisiting    0
# MonthlyIncome               0
# dtype: int64

# %%
pip install feature_engine
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from feature_engine.imputation import EndTailImputer

# %%
x = EndTailImputer(imputation_method='gaussian', tail='right', fold=3)
x
# Out:
# EndTailImputer()

# %%
data=pd.read_csv('https://raw.githubusercontent.com/arijitbose/Feature_engineering/main/Travel.csv')
data
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %%
numerical1 = [feature for feature in data.columns if data[feature].dtype!='O']
numerical1
# Out:
# ['CustomerID',
#  'ProdTaken',
#  'Age',
#  'CityTier',
#  'DurationOfPitch',
#  'NumberOfPersonVisiting',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'Passport',
#  'PitchSatisfactionScore',
#  'OwnCar',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome']

# %%
data[numerical1] = x.fit_transform(data[numerical1])

# %%
data.isnull().sum()
# Out:
# CustomerID                   0
# ProdTaken                    0
# Age                          0
# TypeofContact               25
# CityTier                     0
# DurationOfPitch              0
# Occupation                   0
# Gender                       0
# NumberOfPersonVisiting       0
# NumberOfFollowups            0
# ProductPitched               0
# PreferredPropertyStar        0
# MaritalStatus                0
# NumberOfTrips                0
# Passport                     0
# PitchSatisfactionScore       0
# OwnCar                       0
# NumberOfChildrenVisiting     0
# Designation                  0
# MonthlyIncome                0
# dtype: int64

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
zz = IterativeImputer(n_nearest_features=10, max_iter=100, random_state=30, verbose=True, initial_strategy='mean')
zz
# Out:
# IterativeImputer(max_iter=100, n_nearest_features=10, random_state=30,
#                  verbose=True)

# %%
data1 = pd.read_csv('https://raw.githubusercontent.com/arijitbose/Feature_engineering/main/Travel.csv')
data1
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %%
null3 = [feature for feature in data1.columns if data1[feature].dtype!='O' and data1[feature].isnull().sum()>0]
null3
# Out:
# ['Age',
#  'DurationOfPitch',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome']

# %%
data1[null3] = pd.DataFrame(zz.fit_transform(data1[null3]), columns=[['Age',
 'DurationOfPitch',
 'NumberOfFollowups',
 'PreferredPropertyStar',
 'NumberOfTrips',
 'NumberOfChildrenVisiting',
 'MonthlyIncome']])
data1
# Out:
# [IterativeImputer] Completing matrix with shape (4888, 7)
# [IterativeImputer] Change: 6881.378017687973, scaled tolerance: 98.678
# [IterativeImputer] Change: 519.5708844769802, scaled tolerance: 98.678
# [IterativeImputer] Change: 116.53221372711357, scaled tolerance: 98.678
# [IterativeImputer] Change: 26.131736332709494, scaled tolerance: 98.678
# [IterativeImputer] Early stopping criterion reached.
#       CustomerID  ProdTaken        Age    TypeofContact  CityTier  \
# 0         200000          1  41.000000     Self Enquiry         3
# 1         200001          0  49.000000  Company Invited         1
# 2         200002          1  37.000000     Self Enquiry         1
# 3         200003          0  33.000000  Company Invited         1
# 4         200004          0  33.179594     Self Enquiry         1
# ...          ...        ...        ...              ...       ...
# 4883      204883          1  49.000000     Self Enquiry         3
# ...

# %%
data1.isnull().sum()
# Out:
# CustomerID                   0
# ProdTaken                    0
# Age                          0
# TypeofContact               25
# CityTier                     0
# DurationOfPitch              0
# Occupation                   0
# Gender                       0
# NumberOfPersonVisiting       0
# NumberOfFollowups            0
# ProductPitched               0
# PreferredPropertyStar        0
# MaritalStatus                0
# NumberOfTrips                0
# Passport                     0
# PitchSatisfactionScore       0
# OwnCar                       0
# NumberOfChildrenVisiting     0
# Designation                  0
# MonthlyIncome                0
# dtype: int64

# %%
data = pd.read_csv('https://raw.githubusercontent.com/arijitbose/Feature_engineering/main/Travel.csv')
data
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %%
figure = plt.figure(figsize=(10,7))
ax = plt.subplot(1,1,1)
data['Age'].plot(kind='kde', ax=ax)
data1['Age'].plot(kind='kde', ax=ax)
plt.legend()
